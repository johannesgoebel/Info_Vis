# %%
import sys
import pandas as pd

# %%
co2_gdp = pd.read_csv(r'C:\Users\jog97\OneDrive\Dokumente\Uni\Studium\Master\02_Semester\Info_Vis\data\co2-emissions-and-gdp.csv')
co2_gdp.head
# Out:
# <bound method NDFrame.head of            Entity Code  Year  Annual CO2 emissions  \
# 0     Afghanistan  AFG  1990             2603238.0
# 1     Afghanistan  AFG  1991             2427366.0
# 2     Afghanistan  AFG  1992             1379462.0
# 3     Afghanistan  AFG  1993             1333055.0
# 4     Afghanistan  AFG  1994             1281602.0
# ...           ...  ...   ...                   ...
# 8743     Zimbabwe  ZWE  2016            10737567.0
# 8744     Zimbabwe  ZWE  2017             9581633.0
# 8745     Zimbabwe  ZWE  2018            11854367.0
# 8746     Zimbabwe  ZWE  2019            10949084.0
# 8747     Zimbabwe  ZWE  2020            10531342.0
#
#       Annual consumption-based CO2 emissions           GDP  \
# 0                                        NaN           NaN
# 1                                        NaN           NaN
# 2                                        NaN           NaN
# 3                                        NaN           NaN
# ...

# %%
co2_by_region = pd.read_csv(r"C:\Users\jog97\OneDrive\Dokumente\Uni\Studium\Master\02_Semester\Info_Vis\data\annual-co-emissions-by-region.csv")
climate_change = pd.read_csv(r"C:\Users\jog97\OneDrive\Dokumente\Uni\Studium\Master\02_Semester\Info_Vis\data\climate-change.csv")
net_zero_target_set = pd.read_csv(r"C:\Users\jog97\OneDrive\Dokumente\Uni\Studium\Master\02_Semester\Info_Vis\data\net-zero-target-set.csv")
net_zero_target = pd.read_csv(r"C:\Users\jog97\OneDrive\Dokumente\Uni\Studium\Master\02_Semester\Info_Vis\data\net-zero-targets.csv")
temperature_anomaly = pd.read_csv(r"C:\Users\jog97\OneDrive\Dokumente\Uni\Studium\Master\02_Semester\Info_Vis\data\temperature-anomaly.csv")

# %%
afghanistan = co2_by_region.loc[co2_by_region["Entity"] == 'Afghanistan']
afghanistan.plot(x="Year")

# %%
germany = co2_gdp.loc[co2_gdp["Entity"] == "Germany"]
for col in germany.columns:
    print(col)
# Out:
# Entity
# Code
# Year
# Annual CO2 emissions
# Annual consumption-based CO2 emissions
# GDP
#  PPP (constant 2017 international $)

# %%
ax = germany.plot(x="Year", y="Annual CO2 emissions")
germany.plot(x="Year", y="GDP", ax=ax)
